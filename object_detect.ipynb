# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # downloads automatically, ~6MB

results = model("https://ultralytics.com/images/bus.jpg")  # test image

results[0].show()  # opens a window with detections drawn
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 C:\Users\rudra\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 1145.4ms
# Speed: 11.2ms preprocess, 1145.4ms inference, 44.4ms postprocess per image at shape (1, 3, 640, 480)

# %%
from ultralytics import YOLO
import cv2

model = YOLO("yolov8n.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)

    annotated = results[0].plot()

    cv2.imshow("YOLO Live Detection", annotated)

    if cv2.waitKey(1) & 0xFF == 27:  # ESC
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1084.7ms
# Speed: 2.9ms preprocess, 1084.7ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 chair, 14.3ms
# Speed: 2.5ms preprocess, 14.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 chair, 14.1ms
# Speed: 1.5ms preprocess, 14.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 chair, 19.2ms
# Speed: 2.4ms preprocess, 19.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 1 chair, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 1 chair, 13.4ms
# Speed: 1.5ms preprocess, 13.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 1 chair, 18.8ms
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  

model.train(
    data=r"C:\Users\rudra\Downloads\Compressed\aerial.v1i.yolov8\data.yaml",  # Added 'r' prefix to treat as raw string
    # Alternative solutions:
    # data="C:/Users/rudra/Downloads/Compressed/aerial.v1i.yolov8/data.yaml",  # Using forward slashes
    # data="C:\\Users\\rudra\\Downloads\\Compressed\\aerial.v1i.yolov8\\data.yaml",  # Using double backslashes
    epochs=50,
    imgsz=640,
    batch=8
)
# Out:
# Ultralytics 8.4.19  Python-3.13.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("C:/Users/rudra/runs/detect/train9/weights/best.pt")

results = model("C:/Users/rudra/Downloads/Compressed/aerial.v1i.yolov8/test/images/0000172_00001_d_0000001_jpg.rf.a00a5e29307400ac229b3b39ec1f0f3d.jpg")

results[0].show()
# Out:
# image 1/1 C:\Users\rudra\Downloads\Compressed\aerial.v1i.yolov8\test\images\0000172_00001_d_0000001_jpg.rf.a00a5e29307400ac229b3b39ec1f0f3d.jpg: 640x640 12 cars, 5 motorcycles, 5 persons, 3 trucks, 68.7ms
# Speed: 7.8ms preprocess, 68.7ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import cv2

model = YOLO("C:/Users/rudra/runs/detect/train9/weights/best.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)

    annotated = results[0].plot()

    cv2.imshow("YOLO Live Detection", annotated)

    if cv2.waitKey(1) & 0xFF == 27:  # ESC
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 car, 54.7ms
# Speed: 3.2ms preprocess, 54.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolo26n.pt")
#model = YOLO("C:/Users/rudra/runs/detect/train9/weights/best.pt")


model.predict(
    source="http://192.168.50.234:8080/video",
    show=True,
    conf=0.5
)
# Out:
# 1/1: http://192.168.50.234:8080/video... Success  (inf frames of shape 1920x1080 at 25.00 FPS)
#
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 (no detections), 625.5ms
# 0: 384x640 1 person, 130.0ms
# 0: 384x640 1 person, 84.0ms
# 0: 384x640 1 person, 68.7ms
# 0: 384x640 1 person, 77.1ms
# 0: 384x640 1 person, 127.1ms
# 0: 384x640 1 person, 91.0ms
# 0: 384x640 1 person, 87.5ms
# 0: 384x640 1 person, 80.8ms
# 0: 384x640 1 person, 112.8ms
# ...
